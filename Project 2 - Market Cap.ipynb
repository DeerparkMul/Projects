# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("C:/Users/DR/Desktop/moving computer/UCD CERT in DATA/MarketCap.csv")

# %%
df2 = df[['Data Source','Unnamed: 64']]

# %%
df2
# Out:
#            Data Source   Unnamed: 64
# 0                  NaN           NaN
# 1    Last Updated Date           NaN
# 2                  NaN           NaN
# 3         Country Name  2.020000e+03
# 4                Aruba           NaN
# ..                 ...           ...
# 265             Kosovo           NaN
# 266        Yemen, Rep.           NaN
# 267       South Africa  1.051530e+12
# 268             Zambia           NaN
# 269           Zimbabwe           NaN
#
# [270 rows x 2 columns]

# %%
df2.count()
# Out:
# Data Source    268
# Unnamed: 64     98
# dtype: int64

# %%
df2.loc['']

# %%
df3 = df2.dropna()

# %%
df3
# Out:
#                     Data Source   Unnamed: 64
# 3                  Country Name  2.020000e+03
# 7    Africa Western and Central  7.314785e+10
# 11                   Arab World  3.180260e+12
# 12         United Arab Emirates  2.948320e+11
# 17                    Australia  1.720560e+12
# ..                          ...           ...
# 253         Upper middle income  1.690820e+13
# 255               United States  4.071970e+13
# 261                     Vietnam  1.860090e+11
# 263                       World  9.368620e+13
# 267                South Africa  1.051530e+12
#
# [98 rows x 2 columns]

# %%
df3.count()
# Out:
# Data Source    98
# Unnamed: 64    98
# dtype: int64

# %%
df3.rename(columns = {'Data Source' : 'Country'}, inplace = True)

# %%
df3=df3.iloc[:,:2]

# %%
df3
# Out:
#                         Country           Cap
# 3                  Country Name  2.020000e+03
# 7    Africa Western and Central  7.314785e+10
# 11                   Arab World  3.180260e+12
# 12         United Arab Emirates  2.948320e+11
# 17                    Australia  1.720560e+12
# ..                          ...           ...
# 253         Upper middle income  1.690820e+13
# 255               United States  4.071970e+13
# 261                     Vietnam  1.860090e+11
# 263                       World  9.368620e+13
# 267                South Africa  1.051530e+12
#
# [98 rows x 2 columns]

# %%
y=df3['Cap']

# %%
TOP_CAP_TITLE = 'First 10 market capitalization'
TOP_CAP_YLABEL = '% of total cap'

df10 = df3[:10].set_index('Country')
df11 = df10.assign(market_cap_perc = lambda x: (x.Cap / df3.Cap.sum())*100)
ax = df11.market_cap_perc.plot.bar(title=TOP_CAP_TITLE)
ax.set_ylabel(TOP_CAP_YLABEL);

# %%
COLORS = ['orange', 'green', 'orange', 'cyan', 'cyan', 'blue', 'silver', 'orange', 'red', 'green']
ax =df11.market_cap_perc.plot.bar(title=TOP_CAP_TITLE,logy=True, color=COLORS)
ax.set_ylabel('USD');
ax.set_xlabel("")
# Out:
# Text(0.5, 0, '')

# %%
df
# Out:
#            Data Source World Development Indicators  \
# 0                  NaN                          NaN
# 1    Last Updated Date                   08/04/2022
# 2                  NaN                          NaN
# 3         Country Name                 Country Code
# 4                Aruba                          ABW
# ..                 ...                          ...
# 265             Kosovo                          XKX
# 266        Yemen, Rep.                          YEM
# 267       South Africa                          ZAF
# 268             Zambia                          ZMB
# 269           Zimbabwe                          ZWE
#
#                                             Unnamed: 2      Unnamed: 3  \
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# 2                                                  NaN             NaN
# ...

# %%
volatility = df[['Data Source','Unnamed: 55', 'Unnamed: 64']]


volatility = volatility.dropna()


volatility = volatility.sort_values('Unnamed: 64')


volatility.head()
# Out:
#         Data Source   Unnamed: 55   Unnamed: 64
# 3      Country Name  2.011000e+03  2.020000e+03
# 31          Bermuda  1.232340e+09  2.204000e+08
# 56   Cayman Islands  2.275900e+09  6.443200e+08
# 175         Namibia  1.152430e+06  1.867170e+09
# 52       Costa Rica  1.498420e+09  1.901280e+09

# %%
volatility.rename(columns = {'Unnamed: 64' : 'Cap64'}, inplace = True)

# %%
volatility.rename(columns = {'Unnamed: 55' : 'Cap55'}, inplace = True)

# %%
volatility.head()
# Out:
#         Data Source         Cap55         Cap64
# 3      Country Name  2.011000e+03  2.020000e+03
# 31          Bermuda  1.232340e+09  2.204000e+08
# 56   Cayman Islands  2.275900e+09  6.443200e+08
# 175         Namibia  1.152430e+06  1.867170e+09
# 52       Costa Rica  1.498420e+09  1.901280e+09

# %%
#Defining a function with 2 parameters, the series to plot and the title
def top10_subplot(volatility_series, title):
    # Making the subplot and the figure for two side by side plots
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 6))
    
    # Plotting with pandas the barchart for the top 10 losers
    ax = volatility_series[:10].plot.bar(color="darkred", ax=axes[0])
    
    # Setting the figure's main title to the text passed as parameter
    # ... YOUR CODE FOR TASK 7 ...
    fig.suptitle(title)
    # Setting the ylabel to '% change'
    # ... YOUR CODE FOR TASK 7 ...
    ax.set_ylabel('Market Cap')
    # Same as above, but for the top 10 winners
    ax = volatility_series[-10:].plot.bar(color="darkblue", ax=axes[1])
    
    # Returning this for good practice, might use later
    return fig, ax
DTITLE = "Biggest and Smallest"
fig, ax = top10_subplot(volatility.Cap64, DTITLE)

# %%
volatility['per change']=volatility['Cap64']/volatility['Cap55']

# %%
volatility.head()
# Out:
#         Data Source         Cap55         Cap64       Change
# 3      Country Name  2.011000e+03  2.020000e+03     1.004475
# 31          Bermuda  1.232340e+09  2.204000e+08     0.178847
# 56   Cayman Islands  2.275900e+09  6.443200e+08     0.283106
# 175         Namibia  1.152430e+06  1.867170e+09  1620.202529
# 52       Costa Rica  1.498420e+09  1.901280e+09     1.268857

# %%
DTITLE = "Biggest and Smallest % change"
fig, ax = top10_subplot(volatility2.Change, DTITLE)

# %%
volatility.rename(columns = {'per change' : 'Change'}, inplace = True)

# %%
volatility2=volatility.sort_values('Change')

# %%
volatility2['Change'].nlargest()
# Out:
# 175    1620.202529
# 116      11.377253
# 209       7.168172
# 261       7.164768
# 242       5.183964
# Name: Change, dtype: float64

# %%
volatility3['Change'].nlargest()
# Out:
# Data Source
# Iran, Islamic Rep.                                   11.377253
# Saudi Arabia                                          7.168172
# Vietnam                                               7.164768
# Middle East & North Africa (IDA & IBRD countries)     5.183964
# Middle East & North Africa                            5.176624
# Name: Change, dtype: float64

# %%
volatility3=volatility2.drop(labels=175, axis=0)

# %%
DTITLE = "Biggest and Smallest % change excluding Namibia"
fig, ax = top10_subplot(volatility3.Change, DTITLE)

# %%
volatility.set_index('Cap64')
# Out:
#                             Data Source         Cap55       Change
# Cap64
# 2.020000e+03               Country Name  2.011000e+03     1.004475
# 2.204000e+08                    Bermuda  1.232340e+09     0.178847
# 6.443200e+08             Cayman Islands  2.275900e+09     0.283106
# 1.867170e+09                    Namibia  1.152430e+06  1620.202529
# 1.901280e+09                 Costa Rica  1.498420e+09     1.268857
# ...                                 ...           ...          ...
# 4.336130e+13              North America  1.755480e+13     2.470054
# 6.082030e+13               OECD members  3.410220e+13     1.783471
# 6.628170e+13  Post-demographic dividend  3.553510e+13     1.865246
# 7.168350e+13                High income  3.734330e+13     1.919581
# 9.368620e+13                      World  4.752130e+13     1.971457
#
# [93 rows x 3 columns]

# %%
def capcount(query_string):
    return volatility.query(query_string).count().Cap64


LABELS = ["Big", "Medium", "Small"]


Big= capcount("Cap64 > 2E+13")


Medium =  capcount("Cap64 >= 1.2E+12 & Cap64 < 2E+13")


Small =   capcount("Cap64 < 1.2E+12")


values = [Big,Medium,Small]


plt.bar(range(len(values)), values, tick_label=LABELS);
