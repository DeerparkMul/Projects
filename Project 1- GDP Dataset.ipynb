# %% [markdown]
# In this project I used a dataset about the gdp of all the countries in the world from 1990 to 2019.
# Part One
# Firstly I broke the data in two and looked at the difference between the data before and after 2003.
# I looked at the gdp in the Arab world and I got a 95% confidence interval as to was the difference between the two group of years should be.
# Part Two
# I graphed the gdp of France and Ireland using both line charts and scatter plots
# I created a basic function predicting Irish GDP based on French GDP
# I plotted the annual percentage change in both Irish and French GDP and then plotted the difference between these two figures

# %%
import pandas as pd

# %%
df_gdp= pd.read_csv('C:/Users/DR/Desktop/moving computer/UCD CERT in DATA/GDP.csv', index_col=0)

# %%
df_gdp
# Out:
#              Country Code          1990          1991          1992  \
# Country
# Aruba                 ABW  24101.109430  25870.755940  26533.343900
# Afghanistan           AFG           NaN           NaN           NaN
# Angola                AGO   3089.683369   3120.356148   2908.160798
# Albania               ALB   2549.473022   1909.114038   1823.307673
# Arab World            ARB   6808.206995   6872.273195   7255.328362
# ...                   ...           ...           ...           ...
# Kosovo                XKX           NaN           NaN           NaN
# Yemen, Rep.           YEM   2223.028771   2325.263661   2443.920401
# South Africa          ZAF   6424.502215   6414.057923   6261.716184
# Zambia                ZMB   1517.926292   1528.781247   1499.340446
# Zimbabwe              ZWE   1829.677575   1949.732966   1777.843425
#
#                       1993          1994          1995          1996  \
# Country
# ...

# %%
df_gdp_before=df_gdp.iloc[:,0:15]

# %%
df_gdp_before
# Out:
#              Country Code          1990          1991          1992  \
# Country
# Aruba                 ABW  24101.109430  25870.755940  26533.343900
# Afghanistan           AFG           NaN           NaN           NaN
# Angola                AGO   3089.683369   3120.356148   2908.160798
# Albania               ALB   2549.473022   1909.114038   1823.307673
# Arab World            ARB   6808.206995   6872.273195   7255.328362
# ...                   ...           ...           ...           ...
# Kosovo                XKX           NaN           NaN           NaN
# Yemen, Rep.           YEM   2223.028771   2325.263661   2443.920401
# South Africa          ZAF   6424.502215   6414.057923   6261.716184
# Zambia                ZMB   1517.926292   1528.781247   1499.340446
# Zimbabwe              ZWE   1829.677575   1949.732966   1777.843425
#
#                       1993          1994          1995          1996  \
# Country
# ...

# %%
df_gdp_after=df_gdp.iloc[:,15:30]

# %%
df_gdp_after
# Out:
#                       2004          2005          2006          2007  \
# Country
# Aruba         34176.464600  35207.577240  36362.219320  37865.493490
# Afghanistan     885.840819    979.273979   1031.643135   1176.126357
# Angola         3978.697194   4555.185842   5048.876449   5697.251328
# Albania        5422.778462   5865.306196   6559.783257   7276.302969
# Arab World    10937.316090  11646.486090  12442.187940  13041.925530
# ...                    ...           ...           ...           ...
# Kosovo         5476.113407   5983.304400   6390.420478   6983.879200
# Yemen, Rep.    3581.824687   3789.889382   3915.384569   4038.655597
# South Africa   9136.414314   9796.154549  10524.346060  11240.260370
# Zambia         2087.213343   2248.465939   2434.454195   2637.277877
# Zimbabwe       1818.104977   1759.358119   1738.514250   1705.901346
#
#                       2008          2009          2010          2011  \
# Country
# ...

# %%
df_gdp_before2=df_gdp_before.transpose()

# %%
df_gdp_after2=df_gdp_after.transpose()

# %%
df_gdp_after2
# Out:
# Country         Aruba  Afghanistan       Angola       Albania   Arab World  \
# 2004      34176.46460   885.840819  3978.697194   5422.778462  10937.31609
# 2005      35207.57724   979.273979  4555.185842   5865.306196  11646.48609
# 2006      36362.21932  1031.643135  5048.876449   6559.783257  12442.18794
# 2007      37865.49349  1176.126357  5697.251328   7276.302969  13041.92553
# 2008      38515.26380  1218.118215  6221.423373   8228.374239  13739.72775
# 2009      34693.08675  1454.663015  6092.783245   8814.810856  13640.84678
# 2010      33732.84745  1637.377987  6230.297028   9628.025783  14127.77802
# 2011      35492.61849  1626.764793  6346.395122  10207.752350  14518.82745
# 2012      35498.98209  1806.763930  6772.528333  10526.235450  15423.46539
# 2013      37419.89282  1874.765634  6980.423038  10571.010650  15824.78011
# 2014      38223.37226  1897.525938  7199.245478  11259.225890  16153.24486
# ...

# %%
gdp_arab_after=df_gdp_after2["Arab World"]

# %%
gdp_arab_after[1:]
# Out:
# 2005    11646.48609
# 2006    12442.18794
# 2007    13041.92553
# 2008    13739.72775
# 2009    13640.84678
# 2010    14127.77802
# 2011    14518.82745
# 2012    15423.46539
# 2013    15824.78011
# 2014    16153.24486
# 2015    16501.79259
# 2016    16935.38330
# 2017    17099.88939
# 2018    17570.13760
# Name: Arab World, dtype: float64

# %%
gdp_arab_before=df_gdp_before2["Arab World"]

# %%
gdp_arab_before=gdp_arab_before[1:]

# %%
# A bootstrap analysis of the reduction of deaths due to handwashing
boot_mean_diff = []
for i in range(3000):
    boot_before = gdp_arab_before.sample(frac=1, replace=True)
    boot_after = gdp_arab_after.sample(frac=1, replace=True)
    boot_mean_diff.append( boot_after.mean() - boot_before.mean())

# Calculating a 95% confidence interval from boot_mean_diff 
confidence_interval = pd.Series(boot_mean_diff).quantile([0.025, 0.975])
confidence_interval
# Out:
# 0.025    5104.712401
# 0.975    7446.647050
# dtype: float64

# %% [markdown]
# There is a 95% confiendent interval that gdp changed between 5189 dollars and 7407 dollars between these two periods.

# %%
gdp_arab_after.mean()
# Out:
# 14640.252592666664

# %%
gdp_arab_before.mean()
# Out:
# 8328.450389357144

# %%
gdp_world=df_gdp.loc['World',:]

# %%
gdp_france=df_gdp.loc['France']

# %%
gdp_ireland=df_gdp.loc['Ireland']

# %%
gdp_world.head()
# Out:
# Country Code            WLD
# 1990            5498.504312
# 1991            5681.151567
# 1992            5848.111472
# 1993            6037.767326
# Name: World, dtype: object

# %%
gdp_france.head()
# Out:
# Country Code            FRA
# 1990            17624.23797
# 1991            18309.47206
# 1992            18931.86995
# 1993            19175.31268
# Name: France, dtype: object

# %%
gdp_ireland.head()
# Out:
# Country Code            IRL
# 1990            13738.26598
# 1991            14393.94598
# 1992            15110.71462
# 1993            15806.03556
# Name: Ireland, dtype: object

# %%
gdp_ireland.describe()
# Out:
# count        30.00000
# unique       30.00000
# top       69056.04604
# freq          1.00000
# Name: Ireland, dtype: float64

# %%
gdp_ireland=gdp_ireland[1:30,]

# %%
gdp_france=gdp_france[1:30]

# %%
gdp_world=gdp_world[1:30]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot(gdp_france)

# %%
fig, ax = plt.subplots()


ax.plot(gdp_france, color='blue')


ax2 = ax.twinx()


ax2.plot(gdp_ireland, color='green')

plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(gdp_france, gdp_ireland)
ax.set_title('A single plot')
# Out:
# Text(0.5, 1.0, 'A single plot')

# %%
gdp_ireland.shape
# Out:
# (29,)

# %%
gdp_ireland=gdp_ireland[1:29,]

# %%
gdp_ireland.shape
# Out:
# (28,)

# %%
import seaborn as sns

# %%
t_df_gdp=df_gdp.transpose()

# %%
t_df_gdp=t_df_gdp.iloc[1:30,]

# %%
sns.relplot(x="Ireland", y="France",
            data=t_df_gdp,
            kind="scatter")

plt.show()

# %%
import pandas as pd
import numpy as np

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns

# Models
from sklearn.linear_model import LinearRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# Reporting
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

# %%
X = t_df_gdp[['France']] 
y = t_df_gdp['Ireland']

# %%
reg = LinearRegression().fit(X, y)

# %%
reg.predict([[25000]])
# Out:
# array([27435.71171748])

# %%
plt.subplots(figsize=(15,7))

plt.plot(gdp_france, color='blue')




plt.show()

# %%
gdp_change_france=gdp_france.pct_change()

# %%
plt.subplots(figsize=(15,7))

plt.plot(gdp_change_france, color='blue')




plt.show()

# %%
plt.subplots(figsize=(15,7))

plt.plot(gdp_ireland, color='green')




plt.show()

# %%
gdp_change_ireland=gdp_ireland.pct_change()

# %%
plt.subplots(figsize=(15,7))

plt.plot(gdp_change_ireland, color='green')




plt.show()

# %%
excess_returns = gdp_change_ireland.sub(gdp_change_france, axis=0)


excess_returns.plot()

excess_returns.describe()
# Out:
# count    27.000000
# mean      0.034895
# std       0.069228
# min      -0.082489
# 25%       0.005995
# 50%       0.034335
# 75%       0.047746
# max       0.335007
# dtype: float64
